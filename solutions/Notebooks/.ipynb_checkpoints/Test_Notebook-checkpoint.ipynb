# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import subprocess
import time

# %%
exe_dir = "/home/sreekumar/DATA_ANALYSIS_LAB/code"
data_dir = "/home/sreekumar/DATA_ANALYSIS_LAB/solutions/Final_assignment/test"

# %%
"""
Usage: ./generate_source  [-h] [-o <file>] [-s <float>] [-d <float>] [-N <int>] [-f <float>] [-p <float>]
                          [-a <float>] [-r <int>]
  -o, --output=<file>       output file
  -s, --sigma=<float>       standard deviation sigma
  -d, --deltaT=<float>      delta T betwean measurements
  -N, --length=<int>        number of elements
  -f, --freq=<float>        frequency
  -p, --phase=<float>       phase
  -a, --amplitude=<float>   signal amplitude
  -r, --random=<int>        if set to 1, generate random signal
  -h, --help                print this help and exit
"""      

def generate_source(outputFile=None, sigma=0, f=0, A=0, delta_T=None, N=10000, phi=0, r=0):
    if delta_T == None : 
        delta_T = 1/N
       
    dataPath = os.path.join(data_dir, outputFile)
    exe_path = os.path.join(exe_dir, 'generate_source')
    cmd_str = f"{exe_path} -o {dataPath} -s {sigma} -d {delta_T} -N {N} -f {f} -p {phi} -a {A} -r {r}"
    
    #print(cmd_str)
    
    cmd = cmd_str.split(' ')
    process = subprocess.Popen(cmd,stdout=subprocess.PIPE)
    out, err = process.communicate()
    if err:
        print('The process raised an error:', err.decode())
    if out:
        print('The process has an output:', out.decode())

    return

# %%
"""
Usage: ./prober  [-h] [-i <file>] [-o <file>] [-f <float>] [-p <float>] [-t <file>] [-m <int>]
  -i, --input=<file>        input file
  -o, --output=<file>       output file
  -f, --freq=<float>        frequency
  -p, --phase=<float>       phase
  -h, --help                print this help and exit
  -t, --templatebank=<file> template bank file
  -m, --method=<int>        select method to analyze signal 1, 2 or 3
"""

def prober(inputFile, f=0, outputFile=None, phi=0, template=None, mod=0):
    
    exe_path = os.path.join(exe_dir, 'prober')
    cmd_str = f"{exe_path} -i {data_dir}/{inputFile} -o {data_dir}/{outputFile} -m {mod}"
    if template:
        cmd_str += f" -t {data_dir}/{template} "
    else:
        cmd_str += f" -f {f} -p {phi}"
        
    #print(cmd_str)
        
    cmd = cmd_str.split(' ')
    process = subprocess.Popen(cmd,stdout=subprocess.PIPE)
    out, err = process.communicate()
    if err:
        print('The process raised an error:', err.decode())
    if out:
        #print('The process has an output:', out.decode())
        return out.decode().split(' ')
    if os.path.isfile(outputFile):
        print(f"Output generated in file {outputFile}")

    return os.path.join(data_dir, outputFile)
    
    #if err:
        #print('The process raised an error:', err.decode())
    #if out:
        #print('The process has an output:', out.decode())
        
    #if out:
        #if template:
            #print('The process has an output:', out.decode())
        #else:
            #with open(f"{data_dir}/output_S{mod}.txt", "w") as file:
                #print('The process has an output:', out.decode())
                #file.write(out.decode())
                #return f"output_S{mod}.txt"
    #if mod == 3:
        #if template:
            #print(cmd_str)
        #else:
            #data = np.loadtxt(f"{data_dir}/{outputFile}")
            #with open(f"{data_dir}/output_S{mod}.txt", "w") as file:
                #file.write("{0: .1f}".format(data[f][0]) + " {0:.1f}".format(data[f][1]) + " {0:.1f}".format(data[f][2]))
                #file.write("{0}\n".format(data[f]))
                #return f"output_S{mod}.txt"
    
    #return f"output_S{mod}.txt"

# %%
#Define a function to calculate the Mismatch
def mismatch(iFile, resultsFile, mode, freq=0, p=0, nfrq=0, nphi=0):
    #Create a template bank
    if nphi == 0:
        frq = np.linspace(0.01, 1000.0, nfrq)
        with open(f"{data_dir}/temp_bank_{nfrq}.csv", "w") as file:
            for i in range(nfrq):
                file.write("{0} {1}\n".format(frq[i],0))
        tbank = f"temp_bank_{nfrq}.csv"
    else:
        frq = np.linspace(0.01, 1000.0, nfrq)
        ph = np.linspace(0, 2*np.pi, nphi)
        with open(f"{data_dir}/temp_bank_{nfrq}_{nphi}.csv", "w") as file:
            for i in range(nfrq):
                for j in range(nphi):
                    file.write("{0} {1}\n".format(frq[i], ph[j]))
        tbank = f"temp_bank_{nfrq}_{nphi}.csv"
    
    
    OFile_1 = prober(inputFile=iFile, f=freq, outputFile=resultsFile, phi=p, mod=mode)
    prober(inputFile=iFile, outputFile=resultsFile, template=tbank, mod=mode)
    
        
    if mode == 2:
        data1 = np.loadtxt(os.path.join(data_dir, OFile_1))
        s_true = data1[2]
        print("Minimum Value at f: ",s_true)
        data2 = np.loadtxt(os.path.join(data_dir, resultsFile))
        s = np.where(data2[:,2] == np.min(data2[:,2]))
        s_best = data2[:,2][s][0]
        print("Minimum value at best f: ",s_best)
        M = 1 - abs(float(s_true)-float(s_best)/float(s_true))
    else:
        data1 = np.loadtxt(os.path.join(data_dir, OFile_1))
        s_true = data1[2]
        print("Maximum Value at f : ",s_true)
        data2 = np.loadtxt(os.path.join(data_dir, resultsFile))
        s = np.where(data2[:,2] == np.max(data2[:,2]))
        s_best = data2[:,2][s][0]
        print("Maximum value at best f: ",s_best)
        M = 1 - float(s_best)/float(s_true)
    
    print("Mismatch: ",M)
    print("\n")
    
    #if nphi == 0:
        #return f"{freq} {M}"
    #else:
        #return f"{freq} {p} {M}"
        
    return M

# %%
for i in range(1,6):
    print(i)
    generate_source(f"test_signal_{i}.csv", sigma=25, delta_T=1/4096, N=737280, r=1)
# Out:
# 1
# The process has an output: 377.174975
# 2.369469
#
# 2
# The process has an output: 734.040752
# 4.611947
#
# 3
# The process has an output: 91.086659
# 0.571743
#
# 4
# The process has an output: 451.861335
# 2.838784
#
# 5
# The process has an output: 311.521720
# 1.956916

# %%
nfrq = 2500
nphi = 500
#frq = np.linspace(0.0, 1000.0, nfrq)
#phi = np.linspace(0, 2*np.pi, nphi)

#with open(f"{data_dir}/temp_bank_{nfrq}_{nphi}.csv", "w") as file:
    #for i in range(nfrq):
        #for j in range(nphi):
            #file.write("{0} {1}\n".format(frq[i], phi[j]))

#for i in range(1,6):
    #print(i)
prober(f"test_signal_1.csv", outputFile=f"results_test_signal_1_{nfrq}_{nphi}_S1.csv", template=f"temp_bank_{nfrq}_{nphi}.csv", mod=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-06cabac896d5> in <module>
#      11 #for i in range(1,6):
#      12     #print(i)
# ---> 13 prober(f"test_signal_1.csv", outputFile=f"results_test_signal_1_{nfrq}_{nphi}_S1.csv", template=f"temp_bank_{nfrq}_{nphi}.csv", mod=1)
#
# <ipython-input-4-3b10a3671fcf> in prober(inputFile, f, outputFile, phi, template, mod)
#      23     cmd = cmd_str.split(' ')
#      24     process = subprocess.Popen(cmd,stdout=subprocess.PIPE)
# ---> 25     out, err = process.communicate()
#      26     if err:
#      27         print('The process raised an error:', err.decode())
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     924                 self._stdin_write(input)
#     925             elif self.stdout:
# --> 926                 stdout = self.stdout.read()
#     927                 self.stdout.close()
#     928             elif self.stderr:
#
# KeyboardInterrupt:

# %%
def find_parameter(inFile,outFile,tbank,t,mode):
    #prober(inputFile=inFile, outputFile=outFile, template=tbank, mod=mode)
    data = np.loadtxt(os.path.join(data_dir, outFile))
    
    if mode == 2:
        best = np.where(data[:,2] == np.min(data[:,2]))
        print("Minimum value is at f = {0:.3f}Hz".format(data[:,0][best][0]))
        print("Minimum value is at phi = {0:.3f}".format(data[:,1][best][0]))
        print("Minimum Value       = {0:.3f} ({0:.8f})".format(data[:,2][best][0]))
    else:
        best = np.where(data[:,2] == np.max(data[:,2]))
        s = data[:,2]
        s_best = data[:,2][best][0]
        if s_best >= t:
            print("Signal is detected")
            print("Signal is present at f = {0:.3f}Hz".format(data[:,0][best][0]))
            print("Signal is present at p = {0:.3f}".format(data[:,1][best][0]))
            print("Maximum Value       = {0:.3f} ({0:.8f})".format(data[:,2][best][0]))
            print("The value of S is >= the threshold",len(np.where(s >= t)[0]),"times.")
            print(data[np.where(s >= t)[0]])
            #print(data[np.where(s >= t)[0]][:,0])
            print("\n")
            result = "positive"
        elif s_best < t:
            print("Signal is not detected")
            print("Maximum is at f = {0:.3f}Hz".format(data[:,0][best][0]))
            print("Maximum is at p = {0:.3f}".format(data[:,1][best][0]))
            print("Maximum Value       = {0:.3f} ({0:.8f})".format(data[:,2][best][0]))
            print("\n")
            result = "negative"
            
    return result, s_best

# %%
s_list_signal = []
s_all_signal = []

number_of_files = 0

nfrq = 1000
nphi = 100
#frq = np.linspace(0.0, 1000.0, nfrq)
#phi = np.linspace(0, 2*np.pi, nphi)

#with open(f"{data_dir}/temp_bank_{nfrq}_{nphi}.csv", "w") as file:
    #for i in range(nfrq):
        #for j in range(nphi):
            #file.write("{0} {1}\n".format(frq[i], phi[j]))

for i in range(1,6):
    result, s_value = find_parameter(inFile=f"test_signal_{i}.csv", outFile=f"results_test_signal_{i}.csv", tbank=f"temp_bank_{nfrq}_{nphi}.csv", mode=1, t=0.08)
    if result == "positive":
        s_list_signal = np.append(s_list_signal,s_value)
        number_of_files = number_of_files + 1
    s_all_signal = np.append(s_all_signal,s_value)

print(s_list_signal)
print("Number of files where a signal is present:",number_of_files)
# Out:
# Signal is detected
# Signal is present at f = 598.599Hz
# Signal is present at p = 2.856
# Maximum Value       = 0.082 (0.08208250)
# The value of S is >= the threshold 7 times.
# [[5.98599e+02 2.66559e+00 8.03365e-02]
#  [5.98599e+02 2.72906e+00 8.12483e-02]
#  [5.98599e+02 2.79253e+00 8.18302e-02]
#  [5.98599e+02 2.85599e+00 8.20825e-02]
#  [5.98599e+02 2.91946e+00 8.20070e-02]
#  [5.98599e+02 2.98293e+00 8.15979e-02]
#  [5.98599e+02 3.04639e+00 8.08654e-02]]
#
#
# Signal is detected
# Signal is present at f = 115.115Hz
# Signal is present at p = 2.856
# Maximum Value       = 0.082 (0.08169110)
# The value of S is >= the threshold 6 times.
# [[1.15115e+02 2.72906e+00 8.08787e-02]
#  [1.15115e+02 2.79253e+00 8.14514e-02]
#  [1.15115e+02 2.85599e+00 8.16911e-02]
#  [1.15115e+02 2.91946e+00 8.16060e-02]
#  [1.15115e+02 2.98293e+00 8.11895e-02]
#  [1.15115e+02 3.04639e+00 8.04495e-02]]
#
#
# Signal is detected
# Signal is present at f = 296.296Hz
# Signal is present at p = 5.522
# Maximum Value       = 0.096 (0.09582180)
# The value of S is >= the threshold 20 times.
# [[2.96296e+02 5.01385e+00 8.30981e-02]
#  [2.96296e+02 5.07732e+00 8.59573e-02]
#  [2.96296e+02 5.14079e+00 8.84736e-02]
#  [2.96296e+02 5.20425e+00 9.06306e-02]
#  [2.96296e+02 5.26772e+00 9.24236e-02]
#  [2.96296e+02 5.33119e+00 9.38430e-02]
#  [2.96296e+02 5.39465e+00 9.48854e-02]
#  [2.96296e+02 5.45812e+00 9.55465e-02]
#  [2.96296e+02 5.52159e+00 9.58218e-02]
#  [2.96296e+02 5.58505e+00 9.57107e-02]
#  [2.96296e+02 5.64852e+00 9.52158e-02]
#  [2.96296e+02 5.71199e+00 9.43377e-02]
#  [2.96296e+02 5.77545e+00 9.30795e-02]
#  [2.96296e+02 5.83892e+00 9.14450e-02]
#  [2.96296e+02 5.90239e+00 8.94441e-02]
#  [2.96296e+02 5.96585e+00 8.70809e-02]
#  [2.96296e+02 6.02932e+00 8.43711e-02]
#  [2.96296e+02 6.09279e+00 8.13171e-02]
#  [4.01401e+02 1.96746e+00 8.00509e-02]
#  [4.01401e+02 2.03093e+00 8.00698e-02]]
#
#
# Signal is not detected
# Maximum is at f = 663.664Hz
# Maximum is at p = 6.156
# Maximum Value       = 0.073 (0.07284080)
#
#
# Signal is not detected
# Maximum is at f = 143.143Hz
# Maximum is at p = 3.491
# Maximum Value       = 0.078 (0.07801420)
#
#
# [0.0820825 0.0816911 0.0958218]
# Number of files where a signal is present: 3

# %%
def search_f_ph(datafile, freq=None, phase=None, N_df=100, f_min=0.01, f_max=20, mod=1, N_ph=50, title=None):
    # Make a frequency space from 0.01 to f_max with N_df steps
    #freqs = np.linspace(f_min, f_max, N_df) 
    #phases = np.linspace(0, 2*m.pi, N_ph)

    #tbank = "tb_test_fphi.tb" # can parametrise this later
    
    # Generate template bank with this frequency space
    # You can also add phase space if feeling like doing a 3D plot
    #with open(os.path.join(data_dir,tbank) ,'w') as tbfile:
        #for f in freqs:
            #for ph in phases:
                #tbfile.write("{0} {1}\n".format(f,ph))

    #results_file = prober(datafile, outputFile=f"results_test_signal_{i}_{nfrq}_{nphi}_S1.csv", template=f"temp_bank_{nfrq}_{nphi}.csv", mode=1)
    results = np.loadtxt(os.path.join(data_dir, f"results_test_signal_2_1000_100_S1.csv"))
    
    # Plotting
    plt.figure(figsize=(15,4))
    if mod == 3:
        ### This is justa Fourier transform, template bank ignored 1/N frequencies tested
        best = np.where(results[:,2] == np.max(results[:,2]))
        plt.plot(results[:,0], results[:,2])
        plt.xscale('log')
        plt.xlabel("f [Hz]")
        plt.show()
        plt.close()
        
        #print(results[:,0][best][0], 0, results[:,2][best][0])
        
        return (results[:,0][best][0], 0, results[:,2][best][0])
    
    levels = np.linspace(np.min(results[:,2]),np.max(results[:,2]),50)
    CS = plt.contourf(results[:,0].reshape(N_df,N_ph),results[:,1].reshape(N_df,N_ph),results[:,2].reshape(N_df,N_ph),levels)
    
    if (freq and phase):
        plt.scatter(freq,phase,marker="x", label="Injection point")
    
    # Plot best match
    if mod == 1 :
        # For S_1 get the maximum
        plt.scatter(results[np.argmax(results[:,2])][0], results[np.argmax(results[:,2])][1], marker="o", label="Loudest point")
        best_phi, best_f, best_val = results[np.argmax(results[:,2])]
    elif mod == 2: 
        # For S_2 get the minimum
        plt.scatter(results[np.argmin(results[:,2])][0], results[np.argmin(results[:,2])][1], marker="o", label="Loudest point")
        best_phi, best_f, best_val = results[np.argmin(results[:,2])]
        
    plt.title(f"Searching over frequency and phase - 2D search $S_{mod}$")
    plt.legend(loc='best')
    plt.xlabel("Frequency [Hz]")
    plt.ylabel("Phase")
    plt.colorbar(CS, label="Prober output")
    plt.show()
    plt.close()
    
    ### Caluclate amplitude (look at data at peak)
    print(best_phi, best_f, best_val)
    
    return (best_phi, best_f, best_val)

# %%
def task5(iFile, oFile, mode):          
    nfrq = 1000
    nphi = 100
    #freq = np.linspace(0.01, 1000.0, nfrq)
    #phi = np.linspace(0, 2*np.pi, nphi)

    #with open(f"{data_dir}/temp_bank_task5.csv", "w") as file:
        #for i in range(nfrq):
            #for j in range(nphi):
                #file.write("{0} {1}\n".format(freq[i], phi[j]))
                
    #prober(inputFile=iFile, outputFile=oFile, template="temp_bank_task5.csv", mod=mode)
    
    data = np.loadtxt(os.path.join(data_dir, oFile))
   
    plt.figure(figsize=(15,4))

    if mode == 3:
        plt.plot(data[:,0],data[:,2])
    else:
        f = data[:,0]
        p = data[:,1]
        S = data[:,2]
        S = np.reshape(S, (nfrq,nphi))
        f = np.reshape(f, (nfrq,nphi))
        p = np.reshape(p, (nfrq,nphi))
        plt.contourf(f,p,S)
        plt.colorbar()
    
    #S_2 searching for the minimum value
    if mode == 2:
        plt.scatter(data[np.argmin(data[:,2])][0], data[np.argmin(data[:,2])][1], marker="o", label="Loudest point")
        best = np.where(data[:,2] == np.min(data[:,2]))
        #print("Frequency  f = {0:.3f}Hz".format(freq))
        print("Minimum value is at f = {0:.3f}Hz".format(data[:,0][best][0]))
        print("Minimum value is at phi = {0:.3f}".format(data[:,1][best][0]))
        print("Minimum Value       = {0:.3f} ({0:.8f})".format(data[:,2][best][0]))
    else:
        plt.scatter(data[np.argmax(data[:,2])][0], data[np.argmax(data[:,2])][1], marker="o", label="Loudest point")
        best = np.where(data[:,2] == np.max(data[:,2]))
        #print("Frequency  f = {0:.3f}Hz".format(freq))
        print("Maximum value is at f = {0:.3f}Hz".format(data[:,0][best][0]))
        print("Maximum value is at phi = {0:.3f}".format(data[:,1][best][0]))
        print("Maximum Value       = {0:.3f} ({0:.8f})".format(data[:,2][best][0]))

# %%
task5(iFile=f"test_signal_2.csv", oFile=f"results_test_signal_2_1000_100_S1.csv", mode=1)
plt.xlim([105.115, 125.115])
# Out:
# Maximum value is at f = 115.115Hz
# Maximum value is at phi = 2.856
# Maximum Value       = 0.082 (0.08169110)
# (105.115, 125.115)

# %%
search_f_ph(f"test_signal_2.csv", freq=None, phase=None, N_df=1000, f_min=0.01, f_max=1000, mod=1, N_ph=100, title=None)
#plt.xlim([550.0, 650.0])
# Out:
# 115.115 2.85599 0.0816911
# (115.115, 2.85599, 0.0816911)

# %%
def get_mismatch(datafile, freq=None, N_df=300, f_min=0.5, f_max=100.5, mod=1):
    # Make a frequency space from 0.01 to f_max with N_df steps
    # This time try to minimise the number of templates in the bank
    # such that you still get good detection
    freqs = np.linspace(f_min, f_max, N_df) 
    tbank = "tb_mismatch.tb" 
    
    # Generate template bank with this frequency space
    with open(os.path.join(data_dir,tbank) ,'w') as tbfile:
        for f in freqs:
            tbfile.write("{0} {1}\n".format(f,0))

    results_file = prober(datafile, templateFile=tbank, mod=mod)
    results = np.loadtxt(results_file)
    
    if mod == 3:
        best = np.where(results[:,2] == np.max(results[:,2]))
        resultsf_tv = prober(datafile, f=freq, mod=3)
        results_tv = np.loadtxt(resultsf_tv)
        S_best = results[:,2][best][0]
        S_tv = np.max(results_tv)
        M_i = 1 - (S_best/S_tv)
        
        return M_i
    
    # Plot best match
    if mod == 1 :
        # For S_1 get the maximum
        best_phi, best_f, best_val = results[np.argmax(results[:,2])]
        tv_phi, tv_f, tv_val = prober(datafile, f=freq, mod=1)
        M_i = 1 - float(best_val)/float(tv_val)
    elif mod == 2: 
        best_phi, best_f, best_val = results[np.argmin(results[:,2])]
        tv_phi, tv_f, tv_val = prober(datafile, f=freq, mod=2)
        M_i = 1 - abs(float(tv_val)-float(best_val)/float(tv_val))
        

    return M_i
# Out:
# [-0.0816917  -0.07605781 -0.07042392 -0.06479003 -0.05915614 -0.05352225
#  -0.04788836 -0.04225447 -0.03662058 -0.03098669 -0.0253528  -0.01971891
#  -0.01408502 -0.00845113 -0.00281724  0.00281664  0.00845053  0.01408442
#   0.01971831  0.0253522   0.03098609  0.03661998  0.04225387  0.04788776
#   0.05352165  0.05915554  0.06478943  0.07042332  0.07605721  0.0816911 ]

# %%
results_n_10 = []
results_s_10 = []

#n = 1000
#freq = np.linspace(95, 105, n)
with open(f"{data_dir}/hist_tbank.csv", "w") as file:
    for i in range(n):
        file.write("{0} {1}\n".format(60,0))

for i in range(100):
    print(f"noise_ROC_{i}.csv")
    generate_source(f"noise_ROC_{i}.csv", sigma=10, delta_T=1/4096, N=737280)
    prober(f"noise_ROC_{i}.csv", outputFile=f"results_noise_{i}_S3.csv", template="hist_tbank.csv", mod=1)
    data6 = np.loadtxt(os.path.join(data_dir, f"results_noise_{i}_S3.csv"))
    results_n_10 = np.append(results_n_25, data6[:,2])    
    print(f"signal_ROC_{i}.csv")
    generate_source(f"signal_ROC_{i}.csv", sigma=10, A=1, f=60, delta_T=1/4096, N=737280, phi=0)
    prober(f"signal_ROC_{i}.csv", outputFile=f"results_signal_{i}_S3.csv", template="hist_tbank.csv", mod=1)
    data7 = np.loadtxt(os.path.join(data_dir, f"results_signal_{i}_S3.csv"))
    results_s_10 = np.append(results_s_25, data7[:,2])
# Out:
# noise_ROC_0.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12112/3681838532.py in <module>
#      11     print(f"noise_ROC_{i}.csv")
#      12     generate_source(f"noise_ROC_{i}.csv", sigma=10, delta_T=1/4096, N=737280)
# ---> 13     prober(f"noise_ROC_{i}.csv", outputFile=f"results_noise_{i}_S3.csv", template="hist_tbank.csv", mod=1)
#      14     data6 = np.loadtxt(os.path.join(data_dir, f"results_noise_{i}_S3.csv"))
#      15     results_n_10 = np.append(results_n_25, data6[:,2])
#
# /tmp/ipykernel_12112/1049530288.py in prober(inputFile, f, outputFile, phi, template, mod)
#      23     cmd = cmd_str.split(' ')
#      24     process = subprocess.Popen(cmd,stdout=subprocess.PIPE)
# ---> 25     out, err = process.communicate()
#      26     if err:
#      27         print('The process raised an error:', err.decode())
#
# ~/anaconda3/lib/python3.9/subprocess.py in communicate(self, input, timeout)
#    1119                 self._stdin_write(input)
#    1120             elif self.stdout:
# -> 1121                 stdout = self.stdout.read()
#    1122                 self.stdout.close()
#    1123             elif self.stderr:
#
# KeyboardInterrupt:

# %%
plt.hist(results_n_25, bins=50, alpha=0.6, label="n")
plt.hist(results_s_25, bins=50, alpha=0.6, label = "s+n")
plt.legend()
plt.show()
plt.close()

# %%
FP_25 = []
TP_25 = []

for t in np.linspace(-1,1,200):
    FP_25 = np.append(FP_25,len(np.where(results_n_25 >= t)[0])/len(results_n_25))
    TP_25 = np.append(TP_25,len(np.where(results_s_25 >= t)[0])/len(results_s_25))

plt.scatter(FP_25,TP_25,label="Sigma 25")
plt.legend(loc="lower right")
plt.plot([0,1])
plt.show()
plt.close()

# %%
results_n_10 = np.zeros(200)
results_s_10 = np.zeros(200)

#n = 1000
#freq = np.linspace(25, 35, n)
#with open(f"{data_dir}/hist_tbank.csv", "w") as file:
    #for i in range(n):
        #file.write("{0} {1}\n".format(freq[i],0))

for i in range(200):
    print(f"noise_ROC_{i}.csv")
    generate_source(f"noise_ROC_{i}.csv", sigma=10, delta_T=1/4096, N=737280)
    File3 = prober(f"noise_ROC_{i}.csv", f=60, outputFile=f"results_noise_{i}_S1.csv", phi=2.5, mod=1)
    data6 = np.loadtxt(os.path.join(data_dir, File3))
    results_n_10[i] = data6[2]    
    print(f"signal_ROC_{i}.csv")
    generate_source(f"signal_ROC_{i}.csv", sigma=10, A=1, f=60, delta_T=1/4096, N=737280, phi=2.5)
    File4 = prober(f"signal_ROC_{i}.csv", f=60, outputFile=f"results_signal_{i}_S1.csv", phi=2.5, mod=1)
    data7 = np.loadtxt(os.path.join(data_dir, File4))
    results_s_10[i] = data7[2]
# Out:
# noise_ROC_0.csv
# The process has an output: 60 2.5 -0.0112937
#
# signal_ROC_0.csv
# The process has an output: 60 2.5 0.501774
#
# noise_ROC_1.csv
# The process has an output: 60 2.5 -0.00304295
#
# signal_ROC_1.csv
# The process has an output: 60 2.5 0.489156
#
# noise_ROC_2.csv
# The process has an output: 60 2.5 0.0152469
#
# signal_ROC_2.csv
# The process has an output: 60 2.5 0.50313
#
# noise_ROC_3.csv
# The process has an output: 60 2.5 3.84577e-05
#
# signal_ROC_3.csv
# The process has an output: 60 2.5 0.493943
#
# noise_ROC_4.csv
# The process has an output: 60 2.5 -0.00348392
#
# signal_ROC_4.csv
# The process has an output: 60 2.5 0.490559
#
# noise_ROC_5.csv
# The process has an output: 60 2.5 -0.000622277
#
# signal_ROC_5.csv
# The process has an output: 60 2.5 0.5056
#
# noise_ROC_6.csv
# The process has an output: 60 2.5 0.00674467
#
# signal_ROC_6.csv
# The process has an output: 60 2.5 0.499731
#
# noise_ROC_7.csv
# The process has an output: 60 2.5 0.00547094
#
# signal_ROC_7.csv
# The process has an output: 60 2.5 0.509236
#
# noise_ROC_8.csv
# The process has an output: 60 2.5 -0.00401149
#
# signal_ROC_8.csv
# The process has an output: 60 2.5 0.509723
#
# noise_ROC_9.csv
# The process has an output: 60 2.5 0.00492483
#
# signal_ROC_9.csv
# The process has an output: 60 2.5 0.494517
#
# noise_ROC_10.csv
# The process has an output: 60 2.5 -0.00686531
#
# signal_ROC_10.csv
# The process has an output: 60 2.5 0.493999
#
# noise_ROC_11.csv
# The process has an output: 60 2.5 0.0117061
#
# signal_ROC_11.csv
# The process has an output: 60 2.5 0.524655
#
# noise_ROC_12.csv
# The process has an output: 60 2.5 -0.0105611
#
# signal_ROC_12.csv
# The process has an output: 60 2.5 0.511379
#
# noise_ROC_13.csv
# The process has an output: 60 2.5 0.0194412
#
# signal_ROC_13.csv
# The process has an output: 60 2.5 0.480864
#
# noise_ROC_14.csv
# The process has an output: 60 2.5 0.00619188
#
# signal_ROC_14.csv
# The process has an output: 60 2.5 0.490411
#
# noise_ROC_15.csv
# The process has an output: 60 2.5 0.00779954
#
# signal_ROC_15.csv
# The process has an output: 60 2.5 0.501647
#
# noise_ROC_16.csv
# The process has an output: 60 2.5 0.00536672
#
# signal_ROC_16.csv
# The process has an output: 60 2.5 0.501305
#
# noise_ROC_17.csv
# The process has an output: 60 2.5 -0.00778684
#
# signal_ROC_17.csv
# The process has an output: 60 2.5 0.485506
#
# noise_ROC_18.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12112/1335456196.py in <module>
#      10 for i in range(200):
#      11     print(f"noise_ROC_{i}.csv")
# ---> 12     generate_source(f"noise_ROC_{i}.csv", sigma=10, delta_T=1/4096, N=737280)
#      13     File3 = prober(f"noise_ROC_{i}.csv", f=60, outputFile=f"results_noise_{i}_S1.csv", phi=2.5, mod=1)
#      14     data6 = np.loadtxt(os.path.join(data_dir, File3))
#
# /tmp/ipykernel_12112/1969565103.py in generate_source(outputFile, sigma, f, A, delta_T, N, phi, r)
#      25     cmd = cmd_str.split(' ')
#      26     process = subprocess.Popen(cmd,stdout=subprocess.PIPE)
# ---> 27     out, err = process.communicate()
#      28     if err:
#      29         print('The process raised an error:', err.decode())
#
# ~/anaconda3/lib/python3.9/subprocess.py in communicate(self, input, timeout)
#    1119                 self._stdin_write(input)
#    1120             elif self.stdout:
# -> 1121                 stdout = self.stdout.read()
#    1122                 self.stdout.close()
#    1123             elif self.stderr:
#
# KeyboardInterrupt:

# %%
#Define a function to calculate the Mismatch
def mismatch(iFile, resultsFile, tbank, mode, freq=0, p=0, nfrq=0, nphi=0):   
    
    #OFile_1 = prober(inputFile=iFile, f=freq, outputFile=resultsFile, phi=p, mod=mode)
    #prober(inputFile=iFile, outputFile=resultsFile, template=tbank, mod=mode)
    #results = np.loadtxt(os.path.join(data_dir, resultsFile))
    results_file = prober(inputFile=iFile, outputFile=resultsFile, template=tbank, mod=mode)
    results = np.loadtxt(results_file)
    
    
    if mode == 3:
        best = np.where(results[:,2] == np.max(results[:,2]))
        print(best)
        resultsf_tv = prober(inputFile=iFile, f=freq, outputFile=resultsFile, phi=p, mod=mode)
        results_tv = np.loadtxt(resultsf_tv)
        S_best = results[:,2][best][0]
        print(S_best)
        S_tv = np.max(results)
        print(S_tv)
        M_i = 1 - (S_best/S_tv)
        print("Mismatch: ",M_i)
        print("\n")
        
        return M_i
    
    # Plot best match
    if mode == 1 :
        # For S_1 get the maximum
        best_f, best_phi, best_val = results[np.argmax(results[:,2])]
        #data1 = np.loadtxt(os.path.join(data_dir, OFile_1))
        #tv_val = data1[2]
        tv_f, tv_phi, tv_val = prober(inputFile=iFile, f=freq, outputFile=resultsFile, phi=p, mod=mode)
        print("True value of frequency and phase: ", tv_f, tv_phi)
        print("Maximum Value at true f: ",tv_val)
        print("Best value of frequency and phase: ", best_f, best_phi)
        print("Maximum Value at best f: ",best_val)
        M_i = 1 - float(best_val)/float(tv_val)
    elif mode == 2: 
        best_f, best_phi, best_val = results[np.argmin(results[:,2])]
        #data1 = np.loadtxt(os.path.join(data_dir, OFile_1))
        #tv_val = data1[2]
        tv_f, tv_phi, tv_val = prober(inputFile=iFile, f=freq, outputFile=resultsFile, phi=p, mod=mode)
        print("True value of frequency and phase: ", tv_f, tv_phi)
        print("Minimum Value at true f: ",tv_val)
        print("Best value of frequency and phase: ", best_f, best_phi)
        print("Minimum Value at best f: ",best_val)
        M_i = 1 - abs(float(tv_val)-float(best_val)/float(tv_val))
        

    #return M_i
    
    print("Mismatch: ",M_i)
    print("\n")
    
    #if nphi == 0:
        #return f"{freq} {M}"
    #else:
        #return f"{freq} {p} {M}"
        
    return M_i

# %%
data_files = []
nf = 50
frq = np.linspace(10, 1000, nf)
ph = np.linspace(0, 2*np.pi, nf)
for n in range(nf):
    data_files.append(generate_source(f"data_test_0{n}.csv",sigma=25, A=1, f=frq[n], phi=ph[n], delta_T=1/4096, N=737280))
    time.sleep(1)

# %%
#True values of frequency and phase
print(frq)
print(ph)
# Out:
# [  10.           30.20408163   50.40816327   70.6122449    90.81632653
#   111.02040816  131.2244898   151.42857143  171.63265306  191.83673469
#   212.04081633  232.24489796  252.44897959  272.65306122  292.85714286
#   313.06122449  333.26530612  353.46938776  373.67346939  393.87755102
#   414.08163265  434.28571429  454.48979592  474.69387755  494.89795918
#   515.10204082  535.30612245  555.51020408  575.71428571  595.91836735
#   616.12244898  636.32653061  656.53061224  676.73469388  696.93877551
#   717.14285714  737.34693878  757.55102041  777.75510204  797.95918367
#   818.16326531  838.36734694  858.57142857  878.7755102   898.97959184
#   919.18367347  939.3877551   959.59183673  979.79591837 1000.        ]
# [0.         0.12822827 0.25645654 0.38468481 0.51291309 0.64114136
#  0.76936963 0.8975979  1.02582617 1.15405444 1.28228272 1.41051099
#  1.53873926 1.66696753 1.7951958  1.92342407 2.05165235 2.17988062
#  2.30810889 2.43633716 2.56456543 2.6927937  2.82102197 2.94925025
#  3.07747852 3.20570679 3.33393506 3.46216333 3.5903916  3.71861988
#  3.84684815 3.97507642 4.10330469 4.23153296 4.35976123 4.48798951
#  4.61621778 4.74444605 4.87267432 5.00090259 5.12913086 5.25735913
#  5.38558741 5.51381568 5.64204395 5.77027222 5.89850049 6.02672876
#  6.15495704 6.28318531]

# %%
start = time.time()
nfrq = 300
nphi = 25
frequency = np.linspace(10, 1000, nfrq)
phase = np.linspace(0, 2*np.pi, nphi)
with open(f"{data_dir}/temp_bank_{nfrq}_{nphi}.csv", "w") as file:
    for i in range(nfrq):
        for j in range(nphi):
            file.write("{0} {1}\n".format(frequency[i], phase[j]))
        
values = []
m = 1
for n in range(nf):
    print(f"data_test_0{n}.csv")
    values.append(mismatch(f"data_test_0{n}.csv", resultsFile=f"results_test_0{n}_{nfrq}_{nphi}_S{m}.csv", tbank = f"temp_bank_{nfrq}_{nphi}.csv", mode=m, freq=frq[n], p=ph[n]))
plt.scatter(frq,values)
plt.show()
end = time.time()
print("The total time required to complete the proces : ",(end-start)/60,"minutes" )
# Out:
# data_test_00.csv
# True value of frequency and phase:  10 0
# Maximum Value at true f:  0.505762
#
# Best value of frequency and phase:  10.0 0.0
# Maximum Value at best f:  0.505762
# Mismatch:  0.0
#
#
# data_test_01.csv
# True value of frequency and phase:  30.2041 0.128228
# Maximum Value at true f:  0.52814
#
# Best value of frequency and phase:  509.967 6.02139
# Maximum Value at best f:  0.077068
# Mismatch:  0.8540765706062786
#
#
# data_test_02.csv
# True value of frequency and phase:  50.4082 0.256457
# Maximum Value at true f:  0.489211
#
# Best value of frequency and phase:  529.833 5.75959
# Maximum Value at best f:  0.0774326
# Mismatch:  0.8417194216810333
#
#
# data_test_03.csv
# True value of frequency and phase:  70.6122 0.384685
# Maximum Value at true f:  0.48429
#
# Best value of frequency and phase:  735.117 1.309
# Maximum Value at best f:  0.0690076
# Mismatch:  0.8575076916723451
#
#
# data_test_04.csv
# True value of frequency and phase:  90.8163 0.512913
# Maximum Value at true f:  0.478104
#
# Best value of frequency and phase:  903.98 3.92699
# Maximum Value at best f:  0.0685789
# Mismatch:  0.8565607064571725
#
#
# data_test_05.csv
# True value of frequency and phase:  111.02 0.641141
# Maximum Value at true f:  0.477988
#
# Best value of frequency and phase:  867.559 3.14159
# Maximum Value at best f:  0.0741277
# Mismatch:  0.8449172364159769
#
#
# data_test_06.csv
# True value of frequency and phase:  131.224 0.76937
# Maximum Value at true f:  0.509015
#
# Best value of frequency and phase:  718.562 2.87979
# Maximum Value at best f:  0.0714206
# Mismatch:  0.8596886142844513
#
#
# data_test_07.csv
# True value of frequency and phase:  151.429 0.897598
# Maximum Value at true f:  0.538597
#
# Best value of frequency and phase:  814.582 2.61799
# Maximum Value at best f:  0.071854
# Mismatch:  0.8665904191816887
#
#
# data_test_08.csv
# True value of frequency and phase:  171.633 1.02583
# Maximum Value at true f:  0.49718
#
# Best value of frequency and phase:  463.612 2.61799
# Maximum Value at best f:  0.0736463
# Mismatch:  0.8518719578422302
#
#
# data_test_09.csv
# True value of frequency and phase:  191.837 1.15405
# Maximum Value at true f:  0.50801
#
# Best value of frequency and phase:  440.435 0.0
# Maximum Value at best f:  0.0738071
# Mismatch:  0.8547132930454124
#
#
# data_test_010.csv
# True value of frequency and phase:  212.041 1.28228
# Maximum Value at true f:  0.479596
#
# Best value of frequency and phase:  562.943 3.14159
# Maximum Value at best f:  0.0741638
# Mismatch:  0.8453619296241003
#
#
# data_test_011.csv
# True value of frequency and phase:  232.245 1.41051
# Maximum Value at true f:  0.525277
#
# Best value of frequency and phase:  188.796 0.523599
# Maximum Value at best f:  0.0662366
# Mismatch:  0.873901579547553
#
#
# data_test_012.csv
# True value of frequency and phase:  252.449 1.53874
# Maximum Value at true f:  0.519167
#
# Best value of frequency and phase:  221.906 5.23599
# Maximum Value at best f:  0.073297
# Mismatch:  0.858818068174595
#
#
# data_test_013.csv
# True value of frequency and phase:  272.653 1.66697
# Maximum Value at true f:  0.511226
#
# Best value of frequency and phase:  49.7324 4.45059
# Maximum Value at best f:  0.0702893
# Mismatch:  0.8625083622507462
#
#
# data_test_014.csv
# True value of frequency and phase:  292.857 1.7952
# Maximum Value at true f:  0.48695
#
# Best value of frequency and phase:  493.411 1.8326
# Maximum Value at best f:  0.0663081
# Mismatch:  0.8638297566485266
#
#
# data_test_015.csv
# True value of frequency and phase:  313.061 1.92342
# Maximum Value at true f:  0.484668
#
# Best value of frequency and phase:  480.167 2.0944
# Maximum Value at best f:  0.0777195
# Mismatch:  0.8396438386689445
#
#
# data_test_016.csv
# True value of frequency and phase:  333.265 2.05165
# Maximum Value at true f:  0.477003
#
# Best value of frequency and phase:  460.301 2.87979
# Maximum Value at best f:  0.075722
# Mismatch:  0.8412546671614225
#
#
# data_test_017.csv
# True value of frequency and phase:  353.469 2.17988
# Maximum Value at true f:  0.496907
#
# Best value of frequency and phase:  533.144 2.0944
# Maximum Value at best f:  0.0753522
# Mismatch:  0.8483575397408368
#
#
# data_test_018.csv
# True value of frequency and phase:  373.673 2.30811
# Maximum Value at true f:  0.472898
#
# Best value of frequency and phase:  735.117 1.0472
# Maximum Value at best f:  0.075934
# Mismatch:  0.8394283756750927
#
#
# data_test_019.csv
# True value of frequency and phase:  393.878 2.43634
# Maximum Value at true f:  0.499755
#
# Best value of frequency and phase:  76.2207 5.49779
# Maximum Value at best f:  0.070205
# Mismatch:  0.8595211653710317
#
#
# data_test_020.csv
# True value of frequency and phase:  414.082 2.56457
# Maximum Value at true f:  0.510852
#
# Best value of frequency and phase:  728.495 4.18879
# Maximum Value at best f:  0.0664894
# Mismatch:  0.8698460610901004
#
#
# data_test_021.csv
# True value of frequency and phase:  434.286 2.69279
# Maximum Value at true f:  0.483459
#
# Best value of frequency and phase:  622.542 3.40339
# Maximum Value at best f:  0.0720281
# Mismatch:  0.8510150809065505
#
#
# data_test_022.csv
# True value of frequency and phase:  454.49 2.82102
# Maximum Value at true f:  0.527287
#
# Best value of frequency and phase:  721.873 0.261799
# Maximum Value at best f:  0.063779
# Mismatch:  0.8790431017643143
#
#
# data_test_023.csv
# True value of frequency and phase:  474.694 2.94925
# Maximum Value at true f:  0.506386
#
# Best value of frequency and phase:  980.134 1.0472
# Maximum Value at best f:  0.0644527
# Mismatch:  0.872720217383577
#
#
# data_test_024.csv
# True value of frequency and phase:  494.898 3.07748
# Maximum Value at true f:  0.491732
#
# Best value of frequency and phase:  801.338 5.49779
# Maximum Value at best f:  0.0723848
# Mismatch:  0.8527962386015147
#
#
# data_test_025.csv
# True value of frequency and phase:  515.102 3.20571
# Maximum Value at true f:  0.477929
#
# Best value of frequency and phase:  16.6221 2.61799
# Maximum Value at best f:  0.067126
# Mismatch:  0.8595481755658267
#
#
# data_test_026.csv
# True value of frequency and phase:  535.306 3.33394
# Maximum Value at true f:  0.482481
#
# Best value of frequency and phase:  39.7993 5.49779
# Maximum Value at best f:  0.0783655
# Mismatch:  0.8375780600686866
#
#
# data_test_027.csv
# True value of frequency and phase:  555.51 3.46216
# Maximum Value at true f:  0.536005
#
# Best value of frequency and phase:  337.793 0.261799
# Maximum Value at best f:  0.0705513
# Mismatch:  0.8683756681374241
#
#
# data_test_028.csv
# True value of frequency and phase:  575.714 3.59039
# Maximum Value at true f:  0.500625
#
# Best value of frequency and phase:  817.893 5.49779
# Maximum Value at best f:  0.0685309
# Mismatch:  0.8631093133583021
#
#
# data_test_029.csv
# True value of frequency and phase:  595.918 3.71862
# Maximum Value at true f:  0.530533
#
# Best value of frequency and phase:  384.147 5.75959
# Maximum Value at best f:  0.0737961
# Mismatch:  0.8609019608582312
#
#
# data_test_030.csv
# True value of frequency and phase:  616.122 3.84685
# Maximum Value at true f:  0.453527
#
# Best value of frequency and phase:  29.8662 1.8326
# Maximum Value at best f:  0.0742582
# Mismatch:  0.8362650955731412
#
#
# data_test_031.csv
# True value of frequency and phase:  636.327 3.97508
# Maximum Value at true f:  0.521337
#
# Best value of frequency and phase:  516.589 4.97419
# Maximum Value at best f:  0.0864519
# Mismatch:  0.8341727136190219
#
#
# data_test_032.csv
# True value of frequency and phase:  656.531 4.1033
# Maximum Value at true f:  0.538549
#
# Best value of frequency and phase:  235.15 2.61799
# Maximum Value at best f:  0.0692404
# Mismatch:  0.87143156890088
#
#
# data_test_033.csv
# True value of frequency and phase:  676.735 4.23153
# Maximum Value at true f:  0.45099
#
# Best value of frequency and phase:  420.569 0.523599
# Maximum Value at best f:  0.0728985
# Mismatch:  0.8383589436572874
#
#
# data_test_034.csv
# True value of frequency and phase:  696.939 4.35976
# Maximum Value at true f:  0.488445
#
# Best value of frequency and phase:  463.612 3.40339
# Maximum Value at best f:  0.0673824
# Mismatch:  0.8620471086816326
#
#
# data_test_035.csv
# True value of frequency and phase:  717.143 4.48799
# Maximum Value at true f:  0.489469
#
# Best value of frequency and phase:  778.161 4.45059
# Maximum Value at best f:  0.0811657
# Mismatch:  0.8341760152328339
#
#
# data_test_036.csv
# True value of frequency and phase:  737.347 4.61622
# Maximum Value at true f:  0.542946
#
# Best value of frequency and phase:  695.385 3.66519
# Maximum Value at best f:  0.0723711
# Mismatch:  0.8667066338088871
#
#
# data_test_037.csv
# True value of frequency and phase:  757.551 4.74445
# Maximum Value at true f:  0.556187
#
# Best value of frequency and phase:  367.592 5.23599
# Maximum Value at best f:  0.0718301
# Mismatch:  0.8708526089246962
#
#
# data_test_038.csv
# True value of frequency and phase:  777.755 4.87267
# Maximum Value at true f:  0.492457
#
# Best value of frequency and phase:  678.829 3.92699
# Maximum Value at best f:  0.0758861
# Mismatch:  0.8459030940772494
#
#
# data_test_039.csv
# True value of frequency and phase:  797.959 5.0009
# Maximum Value at true f:  0.507012
#
# Best value of frequency and phase:  49.7324 3.40339
# Maximum Value at best f:  0.0674131
# Mismatch:  0.8670384527387912
#
#
# data_test_040.csv
# True value of frequency and phase:  818.163 5.12913
# Maximum Value at true f:  0.473496
#
# Best value of frequency and phase:  1000.0 2.61799
# Maximum Value at best f:  0.0670007
# Mismatch:  0.8584978542585365
#
#
# data_test_041.csv
# True value of frequency and phase:  838.367 5.25736
# Maximum Value at true f:  0.480338
#
# Best value of frequency and phase:  301.371 5.23599
# Maximum Value at best f:  0.069964
# Mismatch:  0.8543442326028755
#
#
# data_test_042.csv
# True value of frequency and phase:  858.571 5.38559
# Maximum Value at true f:  0.480056
#
# Best value of frequency and phase:  778.161 6.02139
# Maximum Value at best f:  0.085801
# Mismatch:  0.8212687686436582
#
#
# data_test_043.csv
# True value of frequency and phase:  878.776 5.51382
# Maximum Value at true f:  0.492286
#
# Best value of frequency and phase:  990.067 1.8326
# Maximum Value at best f:  0.0733041
# Mismatch:  0.8510944857257773
#
#
# data_test_044.csv
# True value of frequency and phase:  898.98 5.64204
# Maximum Value at true f:  0.476175
#
# Best value of frequency and phase:  284.816 0.523599
# Maximum Value at best f:  0.0805242
# Mismatch:  0.8308936840447314
#
#
# data_test_045.csv
# True value of frequency and phase:  919.184 5.77027
# Maximum Value at true f:  0.498859
#
# Best value of frequency and phase:  569.565 3.92699
# Maximum Value at best f:  0.0718792
# Mismatch:  0.8559127929936114
#
#
# data_test_046.csv
# True value of frequency and phase:  939.388 5.8985
# Maximum Value at true f:  0.495351
#
# Best value of frequency and phase:  400.702 4.45059
# Maximum Value at best f:  0.0877343
# Mismatch:  0.8228845808325813
#
#
# data_test_047.csv
# True value of frequency and phase:  959.592 6.02673
# Maximum Value at true f:  0.497902
#
# Best value of frequency and phase:  106.02 0.261799
# Maximum Value at best f:  0.0783848
# Mismatch:  0.8425698229772124
#
#
# data_test_048.csv
# True value of frequency and phase:  979.796 6.15496
# Maximum Value at true f:  0.504336
#
# Best value of frequency and phase:  748.361 2.61799
# Maximum Value at best f:  0.0923545
# Mismatch:  0.8168790250943815
#
#
# data_test_049.csv
# True value of frequency and phase:  1000 6.28319
# Maximum Value at true f:  0.493691
#
# Best value of frequency and phase:  1000.0 0.0
# Maximum Value at best f:  0.493691
# Mismatch:  0.0
# The total time required to complete the proces :  137.01026688814164 minutes

# %%
start = time.time()
nfrq = 300
nphi = 25
frequency = np.linspace(10, 1000, nfrq)
phase = np.linspace(0, 2*np.pi, nphi)
with open(f"{data_dir}/temp_bank_{nfrq}_{nphi}.csv", "w") as file:
    for i in range(nfrq):
        for j in range(nphi):
            file.write("{0} {1}\n".format(frequency[i], phase[j]))
        
values = []
m = 3
for n in range(nf):
    print(f"data_test_0{n}.csv")
    values.append(mismatch(f"data_test_0{n}.csv", resultsFile=f"results_test_0{n}_{nfrq}_{nphi}_S{m}.csv", tbank = f"temp_bank_{nfrq}_{nphi}.csv", mode=m, freq=frq[n], p=ph[n]))
plt.scatter(frq,values)
plt.show()
end = time.time()
print("The total time required to complete the proces : ",(end-start)/60,"minutes" )
# Out:
# data_test_00.csv
# (array([1800]),)
# 139066000000.0
# 139066000000.0
# Mismatch:  0.0
#
#
# data_test_01.csv
# (array([5437]),)
# 114943000000.0
# 114943000000.0
# Mismatch:  0.0
#
#
# data_test_02.csv
# (array([9073]),)
# 62441200000.0
# 62441200000.0
# Mismatch:  0.0
#
#
# data_test_03.csv
# (array([12710]),)
# 113089000000.0
# 113089000000.0
# Mismatch:  0.0
#
#
# data_test_04.csv
# (array([16347]),)
# 122912000000.0
# 122912000000.0
# Mismatch:  0.0
#
#
# data_test_05.csv
# (array([19984]),)
# 83171400000.0
# 83171400000.0
# Mismatch:  0.0
#
#
# data_test_06.csv
# (array([23620]),)
# 77744400000.0
# 77744400000.0
# Mismatch:  0.0
#
#
# data_test_07.csv
# (array([27257]),)
# 140600000000.0
# 140600000000.0
# Mismatch:  0.0
#
#
# data_test_08.csv
# (array([30894]),)
# 131929000000.0
# 131929000000.0
# Mismatch:  0.0
#
#
# data_test_09.csv
# (array([34531]),)
# 88914500000.0
# 88914500000.0
# Mismatch:  0.0
#
#
# data_test_010.csv
# (array([38167]),)
# 77574300000.0
# 77574300000.0
# Mismatch:  0.0
#
#
# data_test_011.csv
# (array([41804]),)
# 148415000000.0
# 148415000000.0
# Mismatch:  0.0
#
#
# data_test_012.csv
# (array([45441]),)
# 133750000000.0
# 133750000000.0
# Mismatch:  0.0
#
#
# data_test_013.csv
# (array([49078]),)
# 65004100000.0
# 65004100000.0
# Mismatch:  0.0
#
#
# data_test_014.csv
# (array([52714]),)
# 95899700000.0
# 95899700000.0
# Mismatch:  0.0
#
#
# data_test_015.csv
# (array([56351]),)
# 128442000000.0
# 128442000000.0
# Mismatch:  0.0
#
#
# data_test_016.csv
# (array([59988]),)
# 108679000000.0
# 108679000000.0
# Mismatch:  0.0
#
#
# data_test_017.csv
# (array([63624]),)
# 57419500000.0
# 57419500000.0
# Mismatch:  0.0
#
#
# data_test_018.csv
# (array([67261]),)
# 104896000000.0
# 104896000000.0
# Mismatch:  0.0
#
#
# data_test_019.csv
# (array([70898]),)
# 136117000000.0
# 136117000000.0
# Mismatch:  0.0
#
#
# data_test_020.csv
# (array([74535]),)
# 101309000000.0
# 101309000000.0
# Mismatch:  0.0
#
#
# data_test_021.csv
# (array([78171]),)
# 63764000000.0
# 63764000000.0
# Mismatch:  0.0
#
#
# data_test_022.csv
# (array([81808]),)
# 141677000000.0
# 141677000000.0
# Mismatch:  0.0
#
#
# data_test_023.csv
# (array([85445]),)
# 136230000000.0
# 136230000000.0
# Mismatch:  0.0
#
#
# data_test_024.csv
# (array([89082]),)
# 84503100000.0
# 84503100000.0
# Mismatch:  0.0
#
#
# data_test_025.csv
# (array([92718]),)
# 80970300000.0
# 80970300000.0
# Mismatch:  0.0
#
#
# data_test_026.csv
# (array([96355]),)
# 123388000000.0
# 123388000000.0
# Mismatch:  0.0
#
#
# data_test_027.csv
# (array([99992]),)
# 144663000000.0
# 144663000000.0
# Mismatch:  0.0
#
#
# data_test_028.csv
# (array([103629]),)
# 76519500000.0
# 76519500000.0
# Mismatch:  0.0
#
#
# data_test_029.csv
# (array([107265]),)
# 103412000000.0
# 103412000000.0
# Mismatch:  0.0
#
#
# data_test_030.csv
# (array([110902]),)
# 111511000000.0
# 111511000000.0
# Mismatch:  0.0
#
#
# data_test_031.csv
# (array([114539]),)
# 129321000000.0
# 129321000000.0
# Mismatch:  0.0
#
#
# data_test_032.csv
# (array([118175]),)
# 65822900000.0
# 65822900000.0
# Mismatch:  0.0
#
#
# data_test_033.csv
# (array([121812]),)
# 92858600000.0
# 92858600000.0
# Mismatch:  0.0
#
#
# data_test_034.csv
# (array([125449]),)
# 129883000000.0
# 129883000000.0
# Mismatch:  0.0
#
#
# data_test_035.csv
# (array([129086]),)
# 97564800000.0
# 97564800000.0
# Mismatch:  0.0
#
#
# data_test_036.csv
# (array([132722]),)
# 70886400000.0
# 70886400000.0
# Mismatch:  0.0
#
#
# data_test_037.csv
# (array([136359]),)
# 150333000000.0
# 150333000000.0
# Mismatch:  0.0
#
#
# data_test_038.csv
# (array([139996]),)
# 130176000000.0
# 130176000000.0
# Mismatch:  0.0
#
#
# data_test_039.csv
# (array([143633]),)
# 85309000000.0
# 85309000000.0
# Mismatch:  0.0
#
#
# data_test_040.csv
# (array([147269]),)
# 78932200000.0
# 78932200000.0
# Mismatch:  0.0
#
#
# data_test_041.csv
# (array([150906]),)
# 117584000000.0
# 117584000000.0
# Mismatch:  0.0
#
#
# data_test_042.csv
# (array([154543]),)
# 118318000000.0
# 118318000000.0
# Mismatch:  0.0
#
#
# data_test_043.csv
# (array([158180]),)
# 72970300000.0
# 72970300000.0
# Mismatch:  0.0
#
#
# data_test_044.csv
# (array([161816]),)
# 83647100000.0
# 83647100000.0
# Mismatch:  0.0
#
#
# data_test_045.csv
# (array([165453]),)
# 134289000000.0
# 134289000000.0
# Mismatch:  0.0
#
#
# data_test_046.csv
# (array([169090]),)
# 111224000000.0
# 111224000000.0
# Mismatch:  0.0
#
#
# data_test_047.csv
# (array([172727]),)
# 61778100000.0
# 61778100000.0
# Mismatch:  0.0
#
#
# data_test_048.csv
# (array([176363]),)
# 116695000000.0
# 116695000000.0
# Mismatch:  0.0
#
#
# data_test_049.csv
# (array([180000]),)
# 132914000000.0
# 132914000000.0
# Mismatch:  0.0
# The total time required to complete the proces :  10.94673582315445 minutes

# %%
start = time.time()
nfrq = 5000
nphi = 500
frequency = np.linspace(10, 1000, nfrq)
phase = np.linspace(0, 2*np.pi, nphi)
with open(f"{data_dir}/temp_bank_{nfrq}_{nphi}.csv", "w") as file:
    for i in range(nfrq):
        for j in range(nphi):
            file.write("{0} {1}\n".format(frequency[i], phase[j]))
        
m = 1
mismatch(f"data_test_02.csv", resultsFile=f"results_test_02_{nfrq}_{nphi}_S{m}.csv", tbank = f"temp_bank_{nfrq}_{nphi}.csv", mode=m, freq=frq[2], p=ph[2])

end = time.time()
print("The total time required to complete the proces : ",(end-start)/60,"minutes" )
# Out:
# True value of frequency and phase:  50.4082 0.256457
# Maximum Value at true f:  0.489211
#
# Best value of frequency and phase:  50.4001 1.90132
# Maximum Value at best f:  0.118843
# Mismatch:  0.7570721018129192
#
#
# The total time required to complete the proces :  907.2324107368787 minutes
